# %%
# Wave-Funktion korrigiert
# plotly Version unten

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import numpy as np

# %%
import numpy as np
import datetime

def asadate(x):
    return datetime.datetime.strptime(x, '%d.%m.%Y %H:%M')

def phi(datum,ref):
    diff=asadate(datum)-asadate(ref)  # gibt ein timedelta Objekt mit Tagen und Sekunden zurück: datetime.timedelta(354, 22980)
    phi=diff.days+diff.seconds/3600/24
    return phi

# print(phi(fullmoon_dates[0],ref_dates[0]))

#Liste der Daten des jeweiligen letzten Ereignisses im Vorjahr
#Ref: https://www.calsky.com/cs.cgi/Moon/8?&lang=de
fullmoon_dates = ["21.12.2010 09:13","10.12.2011 15:36","28.12.2012 11:21","17.12.2013 10:28","06.12.2014 10:26","25.12.2015 12:11","14.12.2016 01:05","03.12.2017 16:47","22.12.2018 18:48","12.12.2019 06:12"]
perigee_dates  = ["27.12.2010 13:24","22.12.2011 03:50","13.12.2012 00:07","04.12.2013 11:02","24.12.2014 17:33","21.12.2015 10:09","13.12.2016 00:35","04.12.2017 09:52","24.12.2018 10:56","18.12.2019 21:27"]
#nodeN: nördlichste Position
maxN_dates     = ["20.12.2010 13:34","10.12.2011 14:35","26.12.2012 22:23","17.12.2013 01:56","07.12.2014 10:01","25.12.2015 08:25","14.12.2016 22:37","05.12.2017 12:42","23.12.2018 12:48","13.12.2019 21:58"]
#http://astropixels.com/ephemeris/moon/moonnodes2001.html
node_dates     = ["21.12.2010 14:08","23.12.2011 11:36","24.12.2012 22:27","28.12.2013 00:21","29.12.2014 09:27","31.12.2015 20:19","19.12.2016 04:46","22.12.2017 10:04","24.12.2018 11:54","26.12.2019 13:01"]
ref_dates      = ["01.01.2011 00:00","01.01.2012 00:00","01.01.2013 00:00","01.01.2014 00:00","01.01.2015 00:00","01.01.2016 00:00","01.01.2017 00:00","01.01.2018 00:00","01.01.2019 00:00","01.01.2020 00:00"]

tropic_y   = 365.242 
tropic_m   = 27.32        #equator
synodic_m  = 29.53        #full moon
anomal_m   = 27.55        #perigee
draconic_m = 27.21        #ascending node    

case = 0         # wählt aus der Liste oben die Daten aus

first_full    = fullmoon_dates[case]
first_perigee = perigee_dates[case]
first_maxN    = maxN_dates[case]          #nördlichste Position
first_node    = node_dates[case]
ref_date      = ref_dates[case]

jahr = asadate(fullmoon_dates[case]).year+1

A_perihel   = 0.05   # Schulbiologiezentrum Hannover: 0.05
A_equinox   = 0.1    # 0.10
A_syzygy    = 0.5    # 0.50 
A_perigee   = 0.3    # 0.20
A_moon_decl = 0      # 0.10
A_node      = 0      # 0.05

off_full      = phi(fullmoon_dates[case],ref_dates[case])
off_perigee   = phi(perigee_dates[case],ref_dates[case])
off_moon_decl = phi(maxN_dates[case],ref_dates[case])-tropic_m/2
off_node      = phi(node_dates[case],ref_dates[case])

# %%
x = np.linspace(0, 365, 2000)
def wave(A,T,PHI):                                    #A: Amplitude (relativ), T: Periode [d], PHI: Verschiebung [d]
    return A*np.sin(2*np.pi/T*x+PHI*2*np.pi)
#   cycle             ampli               period                 phi          
perihel_wave   = wave(A_perihel     , tropic_y      , -87                      )  
equinox_wave   = wave(A_equinox     , tropic_y      , 34.5                     )  
syzygy_wave    = wave(A_syzygy      , synodic_m/2   , off_full-synodic_m/8     )   
perigee_wave   = wave(A_perigee     , anomal_m      , off_perigee-anomal_m/4   )  
moon_decl_wave = wave(A_moon_decl   , tropic_m      , off_moon_decl-tropic_m/8 )
node_wave      = wave(A_node        , draconic_m    , off_node-draconic_m/8    ) 

#plt.style.use('seaborn-whitegrid')
plt.plot(x, equinox_wave, label='equinox')
plt.plot(x, syzygy_wave, label='syzygy')
plt.plot(x, perigee_wave, label='perigee')
plt.plot(x, equinox_wave+syzygy_wave+perigee_wave, linestyle='--', label='sum', linewidth=1, color='blue')
plt.legend();

# %%
# Quelle: https://www.youtube.com/watch?v=XUNaGFa9xCM
# dort gibt es ein weiteres Beispiel mit Widgets und interactive

import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import numpy as np
py.offline.init_notebook_mode(connected=True)
x = np.linspace(0, 365, 2000)

def wave(A,T,PHI):                                    #A: Amplitude (relativ), T: Periode [d], PHI: Verschiebung [d]
    return A*np.sin(2*np.pi/T*x+PHI)
#   cycle             ampli               period                 phi          
perihel_wave   = wave(A_perihel     , tropic_y      , -87                      )  
equinox_wave   = wave(A_equinox     , tropic_y/2    , 1                    )  
syzygy_wave    = wave(A_syzygy      , synodic_m/2   , off_full-synodic_m/8     )   
perigee_wave   = wave(A_perigee     , anomal_m      , off_perigee-anomal_m/4   )  
moon_decl_wave = wave(A_moon_decl   , tropic_m      , off_moon_decl-tropic_m/8 )
node_wave      = wave(A_node        , draconic_m    , off_node-draconic_m/8    ) 

layout = go.Layout(
    title='Tidal Forces',
    yaxis=dict(
        title='amplitude'
    ),
)

trace1 = go.Scatter(
    x=x,
    y=equinox_wave,
    mode='lines',
    name='equinox',
    line=dict(
        shape='spline',
        dash='dot'
    )
)
trace2 = go.Scatter(
    x=x,
    y=syzygy_wave,
    mode='lines',
    name='syzygy',
    line=dict(
        shape='spline',
        dash='dot'
    )
)
trace3 = go.Scatter(
    x=x,
    y=perigee_wave,
    mode='lines',
    name='perigee',
    line=dict(
        shape='spline',
        dash='dot'
    )
)
trace4 = go.Scatter(
    x=x,
    y=perigee_wave+syzygy_wave+equinox_wave,
    mode='lines',
    name='sum',
    line=dict(
        shape='spline',
        width=2
    )
)

fig = go.Figure(data=[trace1, trace2, trace3,trace4], layout=layout)
py.offline.iplot(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="8f130028-83e7-44a9-912f-4595d594a03b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8f130028-83e7-44a9-912f-4595d594a03b", [{"type": "scatter", "x": [0.0, 0.18259129564782392, 0.36518259129564784, 0.5477738869434717, 0.7303651825912957, 0.9129564782391196, 1.0955477738869435, 1.2781390695347674, 1.4607303651825914, 1.6433216608304153, 1.8259129564782393, 2.008504252126063, 2.191095547773887, 2.373686843421711, 2.556278139069535, 2.7388694347173588, 2.9214607303651827, 3.1040520260130067, 3.2866433216608306, 3.4692346173086546, 